# %% [markdown]
# # Reloading packages
# It is required to first set up the python environnement (we used a python 3.13.5 virtual environnement) by running
#
#     `pip install -r requirements.txt`.
#
# The following cell makes sure everything is setup correctly and enables autoreload for Jupyter notebooks.

# %%
# %pip install -r requirements.txt
# %pip install --upgrade pip
# %load_ext autoreload
# %autoreload 2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Importing python packages
from dataclasses import dataclass

# Importing everything
from tools.problems import *
from tools.utils_cm_hypersphere import *
from tools.perform_directsearch import perform_ds, saveperform_ds, ds_key, directsearch
from tools.plotandsave_dataprofile import plotting_dp
from tools.saveprint_tables import performancetable

# Plotting parameters 
plt.rcParams.update({
    'font.family': 'serif',  
    'font.serif': ['cm'],  
    'text.usetex': True,
    # 'font.size' : 10,
    # "axes.labelsize": 10,
    # "legend.fontsize": 8,
    # "xtick.labelsize": 8,
    # "ytick.labelsize": 8,
    'figure.figsize' : (6.4, 4.0),
    # "pgf.texsystem": "pdflatex",
})
 
# Fixing the seed
np.random.seed(1)

# %% [markdown]
# # Performing direct-search
# The following cell runs and stores the result of various direct-search with various PSS characteristics and budget, for various manifolds and problems.

# %%
expnumber = 1
mdims = np.array([2,4,8,16,32])
codims = np.array([0,2,4,8,16,32])
codims_sphere = np.array([1,2,4,8,16,32])
N = 100
nbinstances = 100
saving = True # warning : setting it to True may overwrite result of previous experiments
euclideansimplex = 1

saveperform_ds(expnumber, mdims, codims, N, nbinstances,maniftype= 1,obj = 1,euclideansimplex=euclideansimplex, saving = saving)
saveperform_ds(expnumber, mdims, codims, N, nbinstances,maniftype= 1,obj = 2,euclideansimplex=euclideansimplex, saving = saving)
saveperform_ds(expnumber, mdims, codims, N, nbinstances,maniftype= 1.5,obj = 2,euclideansimplex=euclideansimplex, saving = saving)
saveperform_ds(expnumber, mdims, codims, N, nbinstances,maniftype= 1,obj = 3,euclideansimplex=euclideansimplex, saving = saving)
saveperform_ds(expnumber, mdims, codims_sphere, N, nbinstances,maniftype= 2,obj = 1,euclideansimplex=euclideansimplex, saving = saving)

# %% [markdown]
# # Performance table

# %%
saving = True
expnb = 1
for rotations in [0,1]:
    performancetable(expnb, maniftypeobj = [(1,2),(1,1),(1,3),(2,1)],
            rotations = [rotations],
            euclideansimplexs=[0],
            psstypes = [1,2,3],
            printing = True, saving= saving)
# Out:
# 1-2_1-1_1-3_2-1_
#
# rotation =  0 , euclideansimplex =  0 , psstype =  1
#       ratio
# mdim     2    4    8    16   32
# codim
# 0      0.55 0.59 0.55 0.52 0.48
# 2      0.95 0.84 0.66 0.55 0.47
# 4      0.97 0.95 0.75 0.61 0.51
# 8      0.98 0.98 0.92 0.73 0.56
# 16     0.96 0.98 0.94 0.88 0.63
# 32     0.98 0.97 0.95 0.95 0.75
# 1-2_1-1_1-3_2-1_
#
# rotation =  0 , euclideansimplex =  0 , psstype =  2
#       ratio
# mdim     2    4    8    16   32
# codim
# 0      0.58 0.64 0.58 0.57 0.61
# 2      0.52 0.46 0.50 0.56 0.57
# 4      0.54 0.42 0.45 0.48 0.55
# 8      0.76 0.48 0.46 0.47 0.54
# 16     0.96 0.62 0.49 0.54 0.55
# 32     0.98 0.70 0.62 0.57 0.54
# 1-2_1-1_1-3_2-1_
#
# rotation =  0 , euclideansimplex =  0 , psstype =  3
#       ratio
# mdim     2    4    8    16   32
# codim
# 0      0.58 0.63 0.60 0.62 0.62
# 2      0.63 0.47 0.53 0.58 0.63
# 4      0.85 0.49 0.50 0.58 0.58
# 8      0.98 0.63 0.52 0.54 0.56
# 16     1.00 0.76 0.56 0.60 0.61
# ...

# %% [markdown]
# # Data Profiles

# %%
expnumber = 1
maniftypeobj = [(1,2),(1,1),(1,3),(2,1)]
saving = True

for rotation in [0,1]:
    for lbdfoeuclideansimplex in [0,1]:
        if lbdfoeuclideansimplex == 1:
            euclideansimplex = 1
            plotting_dp(expnumber, maniftypeobj = maniftypeobj, rotations = [rotation], psstypes = [1,2,3], projections = [0,1], euclideansimplex = euclideansimplex,lbdfoeuclideansimplex = lbdfoeuclideansimplex, tau = 1e-2,N = 100,plotcodimsev = True, plotmdimsev = True, saving = saving)
        euclideansimplex = 0
        plotting_dp(expnumber, maniftypeobj = maniftypeobj, rotations = [rotation], psstypes = [1,2,3], projections = [0,1], euclideansimplex = euclideansimplex,lbdfoeuclideansimplex = lbdfoeuclideansimplex, tau = 1e-2,N = 100,plotcodimsev = True, plotmdimsev = True, saving = saving)
# Out:
# computation number =  exp1_maniftype2_obj1_
# computation number =  exp1_maniftype2_obj1_
# computation number =  exp1_maniftype2_obj1_
# computation number =  exp1_maniftype2_obj1_
# computation number =  exp1_maniftype2_obj1_
# computation number =  exp1_maniftype2_obj1_
