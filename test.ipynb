# %%
# %pip install -e .
# %pip install -r ./requirements.txt
# %load_ext autoreload
# %autoreload 2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
a = np.arange(0, 1, 1).tolist()

# %%
from synchronization_rotations import *
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(0)
problem = ProblemSynchRotations(3,3)
a = directsearch(problem, printing=True, budget=10000,projection= 0,rotation=1)
# Out:
# ----starting direct-search----
# it:82, total evals: 1001/10000, loss_per: 7.564e-01, alpha_ds: 3.125e-02, total polls: 9/18
# ----direct-search finished----

# %%
vf = a[0]["vf"]
plt.plot(vf)
